# %% [markdown]
# # Final Report and Insights
#
# **Objective:** Turn the statistical outputs into an executive, policy-oriented narrative supported by reproducible evidence.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from rbi_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.max_columns', 120)

# %%
df = load_cleaned()
summary = {
    'date_min': df['date'].min(),
    'date_max': df['date'].max(),
    'observations': len(df),
    'reserve_money_start': df['reserve_money'].iloc[0],
    'reserve_money_end': df['reserve_money'].iloc[-1],
    'largest_weekly_expansion': df.loc[df['reserve_money_weekly_change'].idxmax(), ['date','reserve_money_weekly_change']],
    'largest_weekly_contraction': df.loc[df['reserve_money_weekly_change'].idxmin(), ['date','reserve_money_weekly_change']],
}
summary

# %%
contrib_cols = [c for c in df.columns if c.endswith('_pct_of_reserve_money')]
latest_contrib = df[['date'] + contrib_cols].tail(1).T
latest_contrib

# %% [markdown]
# ## Interpretation Prompts
#
# Use the outputs above to answer:
#
# - Which component contributes most to reserve money changes?
# - Which weeks show unusual liquidity expansion or contraction?
# - Which variables are strongest drivers in regression and rolling correlation views?
# - How accurate is the forecasting model on the latest holdout year?
# - What limitations should a policy reader keep in mind?

# %%
report_path = PROJECT_ROOT / 'reports' / 'Final_Report_Draft.md'
report_path.write_text('# Final Report: RBI Balance Sheet Analysis\n\nUse this draft with results from the notebooks.\n', encoding='utf-8')
report_path
